# %% [markdown]
# # Breadth_First_Search
#
# Credit:
# 1. https://towardsdatascience.com/search-algorithm-breadth-first-search-with-python-50571a9bb85e
# 2. https://favtutor.com/blogs/breadth-first-search-python
# 3. https://www.educative.io/edpresso/how-to-implement-a-breadth-first-search-in-python
# 4. https://stackabuse.com/graphs-in-python-breadth-first-search-bfs-algorithm/

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Time Complexity
# The **time complexity** of the Breadth first Search algorithm is in the form of **O(V+E)**, where
# 1. **V** is the representation of the number of nodes and
# 2. **E** is the number of edges.
#
# # **Space** Complexity
# Also, the space complexity of the BFS algorithm is **O(V).**

# %%
from collections import defaultdict

# Generate adjacency list for undirected graph
def generateAdjacencyList(edges):
    adjacencyList = defaultdict(list)
    for u, v in edges:
        adjacencyList[u].append(v)
        adjacencyList[v].append(u)
    return adjacencyList

edges = [['A', 'B'], ['A', 'C'], ['B', 'D'], ['B', 'E'], ['C', 'F'], ['C', 'G'], ['D', 'H'], ['D', 'I'], ['E', 'J'], ['E', 'K'], ['F', 'L'], ['F', 'M']]
adjacencyList = generateAdjacencyList(edges)
print(adjacencyList)
# Out:
# defaultdict(<class 'list'>, {'A': ['B', 'C'], 'B': ['A', 'D', 'E'], 'C': ['A', 'F', 'G'], 'D': ['B', 'H', 'I'], 'E': ['B', 'J', 'K'], 'F': ['C', 'L', 'M'], 'G': ['C'], 'H': ['D'], 'I': ['D'], 'J': ['E'], 'K': ['E'], 'L': ['F'], 'M': ['F']})

# %%
# find bfs traversal from starting vertex
def bfs(adjacencyList, vertex):
    visitedSet = set()
    queue = []
    visitedSet.add(vertex)
    queue.append(vertex)
    
    result = []
    while queue:
        v = queue[0]
        result.append(v)
        queue = queue[1:]
        for neighbor in adjacencyList[v]:
            if neighbor not in visitedSet:
                visitedSet.add(neighbor)
                queue.append(neighbor)
    return result

print(bfs(adjacencyList, 'A'))
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M']
